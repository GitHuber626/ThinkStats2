# %% [markdown]
# # Week 8 Homework
#
# Examples and Exercises from Think Stats, 2nd Edition
#
# http://thinkstats2.com
#
# Copyright 2016 Allen B. Downey
#
# MIT License: https://opensource.org/licenses/MIT

# %%
from os.path import basename, exists


def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + local)


download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkstats2.py")
download("https://github.com/AllenDowney/ThinkStats2/raw/master/code/thinkplot.py")

# %%
import numpy as np
import pandas as pd

import thinkstats2
import thinkplot

# %% [markdown]
# ## Exercise 11-1
# Suppose one of your co-workers is expecting a baby and you are participating in an office pool to predict the date of birth. Assuming that bets are placed during the 30th week of pregnancy, what variables could you use to make the best prediction? You should limit yourself to variables that are known before the birth, and likely to be available to the people in the pool.

# %%
# Getting the birth data that are more than 30 weeks since the bets are placed during the 30th week
import first
live, firsts, others = first.MakeFrames()
live = live[live.prglngth>30]

# %%
# Checking the columns
live.columns.nunique()
# Out:
# 244

# %%
# Join the data form the respondent table
import nsfg
resp = nsfg.ReadFemResp()
resp.index = resp.caseid
join = live.join(resp, on='caseid', rsuffix='_r')
join.shape
# Out:
# (8884, 3331)

# %%
# Data mining for variables that have prediction power
def GoMining(df, top=30):
    """Searches for variables that predict pregnancey length.

    df: DataFrame of pregnancy records

    returns: list of (rsquared, variable name) pairs sorted by rsquared in descending order, top 30 results by default
    """
    import patsy
    import statsmodels.formula.api as smf
    import re
    variables = []
    for name in df.columns:
        if name != 'prglngth':
            try:
                if df[name].var() < 1e-7:
                    continue
    
                formula = 'prglngth ~ ' + name
                model = smf.ols(formula, data=df)
                if model.nobs < len(df)/2:
                    continue
    
                results = model.fit()
            except (ValueError, TypeError, patsy.PatsyError) as e:
                continue
            
            variables.append((results.rsquared, name))
    
    variables = sorted(variables, key = lambda x: x[0], reverse = True)

    # Reads Stata dictionary files for NSFG data and maps variables names to descriptions
    vars1 = thinkstats2.ReadStataDct('2002FemPreg.dct').variables
    vars2 = thinkstats2.ReadStataDct('2002FemResp.dct').variables

    all_vars = pd.concat([vars1, vars2])
    all_vars.index = all_vars.name

    for r2, name in variables[:top]:
        # remove the _r suffix if any variable name has it
        key = re.sub('_r$', '', name) 
        try:
            # search the description of the variable name
            desc = all_vars.loc[key].desc
        except (KeyError, IndexError):
            print(name, r2)
        else:
            if isinstance(desc, pd.Series):
                desc = desc[0]
            print(name, r2, desc)

# %%
GoMining(join)
# Out:
# wksgest 0.8062434116139245 GESTATIONAL LENGTH OF COMPLETED PREGNANCY (IN WEEKS)
# totalwgt_lb 0.12445743148120214
# birthwgt_lb 0.11977307804917159 BD-3 BIRTHWEIGHT IN POUNDS - 1ST BABY FROM THIS PREGNANCY
# lbw1 0.1037254220458328 LOW BIRTHWEIGHT - BABY 1
# mosgest 0.09562431989592757 GESTATIONAL LENGTH OF COMPLETED PREGNANCY (IN MONTHS)
# prglngth_i 0.022053775796467057 PRGLNGTH IMPUTATION FLAG
# canhaver 0.006050495268196787 DF-1 PHYSICALLY DIFFICULT FOR R TO HAVE A BABY
# datcon01_i 0.005817755299879157 DATCON01 IMPUTATION FLAG
# con1mar1_i 0.00554637613624176 CON1MAR1 IMPUTATION FLAG
# nbrnaliv 0.004577565785536919 BC-2 NUMBER OF BABIES BORN ALIVE FROM THIS PREGNANCY
# mar1con1_i 0.0031508022538629943 MAR1CON1 IMPUTATION FLAG
# anynurse 0.002452024883710213 BH-1 WHETHER R BREASTFED THIS CHILD AT ALL - 1ST FROM THIS PREG
# bfeedwks 0.002369183944665898 DURATION OF BREASTFEEDING IN WEEKS
# pregend1 0.0022493894337988207 BC-1 HOW PREGNANCY ENDED - 1ST MENTION
# marout11_i 0.0022436279681069538 MAROUT11 IMPUTATION FLAG
# rmarout11_i 0.0022436279681069538 RMAROUT11 IMPUTATION FLAG
# marcon11_i 0.0022436279681069538 MARCON11 IMPUTATION FLAG
# cmlastlb 0.0020431424422022726 CM FOR R'S MOST RECENT LIVE BIRTH
# cmlastlb_r 0.0020431424422022726 CM FOR R'S MOST RECENT LIVE BIRTH
# datend02_i 0.002012483392754727 DATEND02 IMPUTATION FLAG
# datcon02_i 0.002012483392754727 DATCON02 IMPUTATION FLAG
# agecon02_i 0.0019882867688760797 AGECON02 IMPUTATION FLAG
# fmarcon5_i 0.0019681593242617534 FMARCON5 IMPUTATION FLAG
# ageprg02_i 0.0019528072368834026 AGEPRG02 IMPUTATION FLAG
# evuseint 0.0018917527758618435 EG-1 USE ANY METHOD IN PREGNANCY INTERVAL?
# paydu 0.001876821903014747 IB-10 CURRENT LIVING QUARTERS OWNED/RENTED, ETC
# marcon03_i 0.001791141040157429 MARCON03 IMPUTATION FLAG
# anymschp 0.0017799984332448338 ANY MEDICAL HELP TO PREVENT MISCARRIAGE
# gestasun_m 0.001657131955013269 BC-5 GESTATIONAL LENGTH OF PREGNANCY IN MONTHS
# hlpmc 0.0016125210616492192 HB-1 EVER RECEIVED MEDICAL HELP TO PREVENT MISCARRIAGE

# %% [markdown]
# According to the top 30 variables in terms of highest R^2, Curren livng quarters owned/rented, etc looks like a single variable that makes the best prediction and is known before the birth.

# %% [markdown]
# ## Exercise 11-3
# If the quantity you want to predict is a count, you can use Poisson regression, which is implemented in StatsModels with a function called `poisson`. It works the same way as `ols` and `logit`. As an exercise, let’s use it to predict how many children a woman has born; in the NSFG dataset, this variable is called `numbabes`.
#
# Suppose you meet a woman who is 35 years old, black, and a college graduate whose annual household income exceeds $75,000. How many children would you predict she has born?

# %%
# Check the variable
join['numbabes'].value_counts()
# Out:
# numbabes
# 2     3105
# 3     2363
# 1     1479
# 4     1152
# 5      432
# 6      164
# 7       93
# 8       54
# 10      18
# 9       12
# 16       7
# 22       5
# Name: count, dtype: int64

# %%
# Look for any age variables
vars1 = thinkstats2.ReadStataDct('2002FemPreg.dct').variables
vars2 = thinkstats2.ReadStataDct('2002FemResp.dct').variables

all_vars = pd.concat([vars1, vars2])
all_vars.index = all_vars.name

pd.set_option('display.max_rows', None)

all_vars[['name','desc']][all_vars.desc.str.contains(r'\bage\b', case=False, na=False)]
# Out:
#                     name                                               desc
# name
# ageatend        ageatend              BC-4B R'S AGE AT PREGNANCY'S END DATE
# hpageend        hpageend         BC-4C FATHER'S AGE AT PREGNANCY'S END DATE
# kidage            kidage  CURRENT AGE (IN MOS) OF R'S CHILD(REN) FROM TH...
# hpagelb          hpagelb    BD-6 FATHER'S AGE AT TIME OF CHILD(REN) S BIRTH
# lastage          lastage  AGE (IN MOS) WHEN CHILD LAST LIVED W/R-1ST FRO...
# frsteatd_n    frsteatd_n  BH-3 AGE (MOS/WKS/DAY) WHEN 1ST SUPPLEMENTED -...
# frsteatd        frsteatd  AGE (IN MOS) WHEN 1ST SUPPLEMENTED - 1ST FROM ...
# ageqtnur_n    ageqtnur_n  BH-5 AGE (MOS/WKS/DAY) WHEN STOPPED BREASTFEED...
# ageqtnur        ageqtnur  AGE (IN MOS) WHEN R'STOPPED NURSING CHILD - 1S...
# lastage2        lastage2  AGE (IN MOS) WHEN CHILD LAST LIVED W/R - 2ND F...
# frsteatd_n2  frsteatd_n2  BH-3 AGE (MOS/WKS/DAY) WHEN 1ST SUPPLEMENTED -...
# frsteatd2      frsteatd2  AGE (IN MOS) WHEN 1ST SUPPLEMENTED - 2ND FROM ...
# ageqtnur_n2  ageqtnur_n2  BH-5 AGE (MOS/WKS/DAY) WHEN STOPPED BREASTFEED...
# ageqtnur2      ageqtnur2  AGE (IN MOS) WHEN R'STOPPED NURSING CHILD - 2N...
# lastage3        lastage3  AGE (IN MOS) WHEN CHILD LAST LIVED W/R - 3RD F...
# frsteatd_n3  frsteatd_n3  BH-3 AGE (MOS/WKS/DAY) WHEN 1ST SUPPLEMENTED -...
# frsteatd3      frsteatd3  AGE (IN MOS) WHEN 1ST SUPPLEMENTED - 3RD FROM ...
# ageqtnur_n3  ageqtnur_n3  BH-5 AGE (MOS/WKS/DAY) WHEN STOPPED BREASTFEED...
# ageqtnur3      ageqtnur3  AGE (IN MOS) WHEN R'STOPPED NURSING CHILD - 3R...
# agepreg          agepreg                           AGE AT PREGNANCY OUTCOME
# agecon            agecon                          AGE AT TIME OF CONCEPTION
# ager                ager                                   AGE AT INTERVIEW
# agescrn          agescrn                                R'S AGE AT SCREENER
# age_a              age_a                          AA-1 R S AGE AT INTERVIEW
# age_r              age_r                               R S AGE AT INTERVIEW
# agescrn          agescrn                                R S AGE AT SCREENER
# fl_rage          fl_rage  WHETHER RS AGE AT SCREENER DIFFERS FROM AGE AT...
# onown              onown  AG-0A WHETHER R EVER LIVE AWAY FROM PARENTS/GU...
# lvsit14f        lvsit14f  AG-3 FEMALE PARENT (FIGURE) LIVING WITH AT AGE 14
# lvsit14m        lvsit14m    AG-4 MALE PARENT (FIGURE) LIVING WITH AT AGE 14
# momfstch        momfstch  AG-9 AGE OF FEMALE PARENT (FIGURE) AT FIRST BIRTH
# mom18              mom18  AG-10 ESTIMATE OF AGE OF FEMALE PARENT (FIGURE...
# intact18        intact18  WHETHER R LIVED IN INTACT FAMILY FROM BIRTH TO...
# onown18          onown18               WHETHER R LIVED ON OWN BEFORE AGE 18
# menarche        menarche                 BA-1 AGE AT FIRST MENSTRUAL PERIOD
# choseage        choseage               BK-9 AGE OF CHILD R PREFERS TO ADOPT
# agemarhx        agemarhx               CB-2 R'S AGE AT MARRIAGE-1ST HUSBAND
# hxagemar        hxagemar         CB-3 HUSBAND S AGE AT MARRIAGE-1ST HUSBAND
# agemarhx2      agemarhx2               CB-2 R'S AGE AT MARRIAGE-2ND HUSBAND
# hxagemar2      hxagemar2         CB-3 HUSBAND S AGE AT MARRIAGE-2ND HUSBAND
# agemarhx3      agemarhx3               CB-2 R'S AGE AT MARRIAGE-3RD HUSBAND
# hxagemar3      hxagemar3         CB-3 HUSBAND S AGE AT MARRIAGE-3RD HUSBAND
# hxagemar4      hxagemar4         CB-3 HUSBAND S AGE AT MARRIAGE-4TH HUSBAND
# hxagemar5      hxagemar5         CB-3 HUSBAND S AGE AT MARRIAGE-5TH HUSBAND
# cpherage        cpherage  CC-3 R'S AGE WHEN BEGAN COHABITING W/CURRENT P...
# cphisage        cphisage  CC-4 PARTNER'S AGE WHEN BEGAN COHABITING - CUR...
# heragecx        heragecx  CD-5 R'S AGE WHEN BEGAN COHABITING W/ 1ST FORM...
# hisagecx        hisagecx  CD-6 PARTNER'S AGE WHEN BEGAN COHABITING - 1ST...
# heragecx2      heragecx2  CD-5 R'S AGE WHEN BEGAN COHABITING W/ 2ND FORM...
# hisagecx2      hisagecx2  CD-6 PARTNER'S AGE WHEN BEGAN COHABITING - 2ND...
# heragecx3      heragecx3  CD-5 R'S AGE WHEN BEGAN COHABITING W/ 3RD FORM...
# hisagecx3      hisagecx3  CD-6 PARTNER'S AGE WHEN BEGAN COHABITING - 3RD...
# heragecx4      heragecx4  CD-5 R'S AGE WHEN BEGAN COHABITING W/ 4TH FORM...
# hisagecx4      hisagecx4  CD-6 PARTNER'S AGE WHEN BEGAN COHABITING - 4TH...
# heragecx5      heragecx5  CD-5 R'S AGE WHEN BEGAN COHABITING W/ 5TH FORM...
# hisagecx5      hisagecx5  CD-6 PARTNER'S AGE WHEN BEGAN COHABITING - 5TH...
# heragecx6      heragecx6  CD-5 R'S AGE WHEN BEGAN COHABITING W/ 6TH FORM...
# hisagecx6      hisagecx6  CD-6 PARTNER'S AGE WHEN BEGAN COHABITING - 6TH...
# heragecx7      heragecx7  CD-5 R'S AGE WHEN BEGAN COHABITING W/ 7TH FORM...
# hisagecx7      hisagecx7  CD-6 PARTNER'S AGE WHEN BEGAN COHABITING - 7TH...
# heragecx8      heragecx8  CD-5 R'S AGE WHEN BEGAN COHABITING W/ 8TH FORM...
# hisagecx8      hisagecx8  CD-6 PARTNER'S AGE WHEN BEGAN COHABITING - 8TH...
# agefstsx        agefstsx               CE-4 AGE AT FIRST SEXUAL INTERCOURSE
# fpage              fpage              CG-4 1ST PARTNER'S AGE AT R'S 1ST SEX
# fprelage        fprelage  CG-4B WAS 1ST SEXUAL PARTNER OLDER/YOUNGER/SAM...
# agesxafm        agesxafm                CG-11 AGE AT 1ST SEX AFTER MENARCHE
# p1yrage          p1yrage  CI-5 AGE AT 1ST SEX WITH 1ST REPORTED PARTNER-...
# p1yhsage        p1yhsage  CI-6 PARTNER'S AGE AT 1ST SEX-1ST REPORTED PAR...
# p1yrage2        p1yrage2  CI-5 AGE AT 1ST SEX WITH 2ND REPORTED PARTNER-...
# p1yhsage2      p1yhsage2  CI-6 PARTNER'S AGE AT 1ST SEX-2ND REPORTED PAR...
# p1yrage3        p1yrage3  CI-5 AGE AT 1ST SEX WITH 3RD REPORTED PARTNER-...
# p1yhsage3      p1yhsage3  CI-6 PARTNER'S AGE AT 1ST SEX-3RD REPORTED PAR...
# p1yrage4        p1yrage4  CI-5 AGE AT 1ST SEX WITH 4TH REPORTED PARTNER-...
# p1yhsage4      p1yhsage4  CI-6 PARTNER'S AGE AT 1ST SEX-4TH REPORTED PAR...
# p1yrage5        p1yrage5  CI-5 AGE AT 1ST SEX WITH 5TH REPORTED PARTNER-...
# p1yhsage5      p1yhsage5  CI-6 PARTNER'S AGE AT 1ST SEX-5TH REPORTED PAR...
# p1yrage6        p1yrage6  CI-5 AGE AT 1ST SEX WITH 6TH REPORTED PARTNER-...
# p1yhsage6      p1yhsage6  CI-6 PARTNER'S AGE AT 1ST SEX-6TH REPORTED PAR...
# p1yrage7        p1yrage7  CI-5 AGE AT 1ST SEX WITH 7TH REPORTED PARTNER-...
# p1yhsage7      p1yhsage7  CI-6 PARTNER'S AGE AT 1ST SEX-7TH REPORTED PAR...
# p1yrage8        p1yrage8  CI-5 AGE AT 1ST SEX WITH 8TH REPORTED PARTNER-...
# p1yhsage8      p1yhsage8  CI-6 PARTNER'S AGE AT 1ST SEX-8TH REPORTED PAR...
# p1yrage9        p1yrage9  CI-5 AGE AT 1ST SEX WITH 9TH REPORTED PARTNER-...
# p1yhsage9      p1yhsage9  CI-6 PARTNER'S AGE AT 1ST SEX-9TH REPORTED PAR...
# p1yrage10      p1yrage10  CI-5 AGE AT 1ST SEX WITH 10TH REPORTED PARTNER...
# p1yhsage10    p1yhsage10  CI-6 PARTNER'S AGE AT 1ST SEX-10TH REPORTED PA...
# p1yrage11      p1yrage11  CI-5 AGE AT 1ST SEX WITH 11TH REPORTED PARTNER...
# p1yhsage11    p1yhsage11  CI-6 PARTNER'S AGE AT 1ST SEX-11TH REPORTED PA...
# p1yrage12      p1yrage12  CI-5 AGE AT 1ST SEX WITH 12TH REPORTED PARTNER...
# p1yhsage12    p1yhsage12  CI-6 PARTNER'S AGE AT 1ST SEX-12TH REPORTED PA...
# p1yrage13      p1yrage13  CI-5 AGE AT 1ST SEX WITH 13TH REPORTED PARTNER...
# p1yhsage13    p1yhsage13  CI-6 PARTNER'S AGE AT 1ST SEX-13TH REPORTED PA...
# p1yrage14      p1yrage14  CI-5 AGE AT 1ST SEX WITH 14TH REPORTED PARTNER...
# p1yhsage14    p1yhsage14  CI-6 PARTNER'S AGE AT 1ST SEX-14TH REPORTED PA...
# p1yrage15      p1yrage15  CI-5 AGE AT 1ST SEX WITH 15TH REPORTED PARTNER...
# p1yhsage15    p1yhsage15  CI-6 PARTNER'S AGE AT 1ST SEX-15TH REPORTED PA...
# p1yrage16      p1yrage16  CI-5 AGE AT 1ST SEX WITH 16TH REPORTED PARTNER...
# p1yhsage16    p1yhsage16  CI-6 PARTNER'S AGE AT 1ST SEX-16TH REPORTED PA...
# p1yrage17      p1yrage17  CI-5 AGE AT 1ST SEX WITH 17TH REPORTED PARTNER...
# p1yhsage17    p1yhsage17  CI-6 PARTNER'S AGE AT 1ST SEX-17TH REPORTED PA...
# p1yrage18      p1yrage18  CI-5 AGE AT 1ST SEX WITH 18TH REPORTED PARTNER...
# p1yhsage18    p1yhsage18  CI-6 PARTNER'S AGE AT 1ST SEX-18TH REPORTED PA...
# p1yrage19      p1yrage19  CI-5 AGE AT 1ST SEX WITH 19TH REPORTED PARTNER...
# p1yhsage19    p1yhsage19  CI-6 PARTNER'S AGE AT 1ST SEX-19TH REPORTED PA...
# p1yrage20      p1yrage20  CI-5 AGE AT 1ST SEX WITH 20TH REPORTED PARTNER...
# p1yhsage20    p1yhsage20  CI-6 PARTNER'S AGE AT 1ST SEX-20TH REPORTED PA...
# agefstus        agefstus                    EB-4 AGE WHEN FIRST USED METHOD
# attnd14          attnd14  IC-3 HOW OFTEN R ATTEND RELIGIOUS SERVICES AT ...
# ager                ager                               R'S AGE AT INTERVIEW
# numkdhh          numkdhh  NUMBER OF BIO/ADOPT/RELATED/LEGAL CHILDREN UND...
# parage14        parage14                PARENTAL LIVING SITUATION AT AGE 14
# agemomb1        agemomb1    AGE OF MOTHER (OR MOTHER-FIGURE) AT FIRST BIRTH
# ageprg01        ageprg01                     AGE WHEN PREGNANCY ENDED - 1ST
# ageprg02        ageprg02                     AGE WHEN PREGNANCY ENDED - 2ND
# ageprg03        ageprg03                     AGE WHEN PREGNANCY ENDED - 3RD
# ageprg04        ageprg04                     AGE WHEN PREGNANCY ENDED - 4TH
# ageprg05        ageprg05                     AGE WHEN PREGNANCY ENDED - 5TH
# ageprg06        ageprg06                     AGE WHEN PREGNANCY ENDED - 6TH
# ageprg07        ageprg07                     AGE WHEN PREGNANCY ENDED - 7TH
# ageprg08        ageprg08                     AGE WHEN PREGNANCY ENDED - 8TH
# ageprg09        ageprg09                     AGE WHEN PREGNANCY ENDED - 9TH
# ageprg10        ageprg10                    AGE WHEN PREGNANCY ENDED - 10TH
# ageprg11        ageprg11                    AGE WHEN PREGNANCY ENDED - 11TH
# ageprg12        ageprg12                    AGE WHEN PREGNANCY ENDED - 12TH
# ageprg13        ageprg13                    AGE WHEN PREGNANCY ENDED - 13TH
# ageprg14        ageprg14                    AGE WHEN PREGNANCY ENDED - 14TH
# ageprg15        ageprg15                    AGE WHEN PREGNANCY ENDED - 15TH
# ageprg16        ageprg16                    AGE WHEN PREGNANCY ENDED - 16TH
# ageprg17        ageprg17                    AGE WHEN PREGNANCY ENDED - 17TH
# ageprg18        ageprg18                    AGE WHEN PREGNANCY ENDED - 18TH
# ageprg19        ageprg19                    AGE WHEN PREGNANCY ENDED - 19TH
# agecon01        agecon01                     AGE WHEN PREGNANCY BEGAN - 1ST
# agecon02        agecon02                     AGE WHEN PREGNANCY BEGAN - 2ND
# agecon03        agecon03                     AGE WHEN PREGNANCY BEGAN - 3RD
# agecon04        agecon04                     AGE WHEN PREGNANCY BEGAN - 4TH
# agecon05        agecon05                     AGE WHEN PREGNANCY BEGAN - 5TH
# agecon06        agecon06                     AGE WHEN PREGNANCY BEGAN - 6TH
# agecon07        agecon07                     AGE WHEN PREGNANCY BEGAN - 7TH
# agecon08        agecon08                     AGE WHEN PREGNANCY BEGAN - 8TH
# agecon09        agecon09                     AGE WHEN PREGNANCY BEGAN - 9TH
# agecon10        agecon10                    AGE WHEN PREGNANCY BEGAN - 10TH
# agecon11        agecon11                    AGE WHEN PREGNANCY BEGAN - 11TH
# agecon12        agecon12                    AGE WHEN PREGNANCY BEGAN - 12TH
# agecon13        agecon13                    AGE WHEN PREGNANCY BEGAN - 13TH
# agecon14        agecon14                    AGE WHEN PREGNANCY BEGAN - 14TH
# agecon15        agecon15                    AGE WHEN PREGNANCY BEGAN - 15TH
# agecon16        agecon16                    AGE WHEN PREGNANCY BEGAN - 16TH
# agecon17        agecon17                    AGE WHEN PREGNANCY BEGAN - 17TH
# agecon18        agecon18                    AGE WHEN PREGNANCY BEGAN - 18TH
# agecon19        agecon19                    AGE WHEN PREGNANCY BEGAN - 19TH
# agebaby1        agebaby1                              AGE AT 1ST LIVE BIRTH
# fmar1age        fmar1age                              AGE AT FIRST MARRIAGE
# agediss1        agediss1               AGE AT DISSOLUTION OF FIRST MARRIAGE
# agedd1            agedd1              AGE AT DIVORCE OR DEATH: 1ST MARRIAGE
# vry1stag        vry1stag  AGE AT FIRST INTERCOURSE (EVEN IF BEFORE MENAR...
# sex1age          sex1age            AGE AT FIRST INTERCOURSE SINCE MENARCHE
# fsexpage        fsexpage  AGE OF R'S FIRST SEXUAL PARTNER AT TIME OF FIR...
# lsexrage        lsexrage  R'S AGE AT LAST OR MOST RECENT SEXUAL INTERCOURSE

# %% [markdown]
# age_r looks like the variable that's fitting the question.

# %%
# Look for any college variables
pd.options.display.max_colwidth = 200
all_vars[all_vars.desc.str.contains(r'\bcollege\b', case=False, na=False)]
# Out:
#          start           type     name fstring
# name
# havedeg     52  <class 'int'>  havedeg     %1f  \
# degrees     53  <class 'int'>  degrees     %1f
#
#                                                           desc   end
# name
# havedeg  AF-10 WHETHER R HAS ANY COLLEGE OR UNIVERSITY DEGREES  53.0
# degrees             AF-11 HIGHEST COLLEGE OR UNIVERSITY DEGREE  54.0

# %%
# Check the havedeg
join.havedeg.unique()
# Out:
# array([ 1., nan,  5.])

# %% [markdown]
# Looks like as long the value is not null, the respondent has a college degree

# %%
# Check the data distribution to confirm the guess above
join.havedeg.value_counts(dropna=False)
# Out:
# havedeg
# NaN    4645
# 1.0    2137
# 5.0    2102
# Name: count, dtype: int64

# %%
# Train the model
import statsmodels.formula.api as smf

formula = ('numbabes ~ age_r + C(race) + havedeg + totincr')
results = smf.poisson(formula, data=join).fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.590692
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           Poisson Regression Results
# ==============================================================================
# Dep. Variable:               numbabes   No. Observations:                 4239
# Model:                        Poisson   Df Residuals:                     4233
# Method:                           MLE   Df Model:                            5
# Date:                Sat, 27 Jul 2024   Pseudo R-squ.:                 0.01338
# Time:                        12:24:33   Log-Likelihood:                -6742.9
# converged:                       True   LL-Null:                       -6834.4
# Covariance Type:            nonrobust   LLR p-value:                 1.292e-37
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.3549      0.069      5.171      0.000       0.220       0.489
# C(race)[T.2]    -0.0559      0.024     -2.300      0.021      -0.103      -0.008
# C(race)[T.3]    -0.0726      0.041     -1.769      0.077      -0.153       0.008
# age_r            0.0207      0.002     12.018      0.000       0.017       0.024
# havedeg          0.0125      0.005      2.368      0.018       0.002       0.023
# totincr         -0.0198      0.003     -6.807      0.000      -0.025      -0.014
# ================================================================================
# """

# %% [markdown]
# According to the text book, totincr increaments at \\$5000, so \\$75000 will be level 15.
# <br>
# For race, 1 will be black.
# <br>
# Therefore, we can make the prediciton based on the following:

# %%
columns = ['age_r', 'race', 'havedeg','totincr']
new = pd.DataFrame([[35,1,1,15]], columns=columns)
results.predict(new)
# Out:
# 0    2.216382
# dtype: float64

# %% [markdown]
# We can predict she has born about 2 to 3 children.

# %% [markdown]
# ## Exercise 11-4
# If the quantity you want to predict is categorical, you can use multinomial logistic regression, which is implemented in StatsModels with a function called `mnlogit`. As an exercise, let’s use it to guess whether a woman is married, cohabitating, widowed, divorced, separated, or never married; in the NSFG dataset, marital status is encoded in a variable called `rmarital`.
#
# Suppose you meet a woman who is 25 years old, white, and a high school graduate whose annual household income is about $45,000. What is the probability that she is married, cohabitating, etc?

# %%
# Check the response variable
live.rmarital.value_counts(dropna=False)
# Out:
# rmarital
# 1    5027
# 6    1403
# 2     914
# 4     860
# 5     575
# 3     105
# Name: count, dtype: int64

# %% [markdown]
# I will assume that 1,2,3,4,5,6 represents: married, cohabitating, widowed, divorced, separated, or never married

# %%
# Check the high school graduate variable
all_vars[all_vars.desc.str.contains(r'\bhigh school\b', case=False, na=False)]
# Out:
#           start           type      name fstring
# name
# havedip      46  <class 'int'>   havedip     %1f  \
# dipged       47  <class 'int'>    dipged     %1f
# cmhsgrad     48  <class 'int'>  cmhsgrad     %4f
#
#                                                               desc   end
# name
# havedip      AF-5 WHETHER R HAS HIGH SCHOOL DIPLOMA OR GED OR BOTH  47.0
# dipged    AF-6 WHICH ONE R HAS: HIGH SCHOOL DIPLOMA OR GED OR BOTH  48.0
# cmhsgrad                   CENTURY MONTH OF HIGH SCHOOL GRADUATION  52.0

# %%
# Check the havedip variable
join.havedip.value_counts(dropna=False)
# Out:
# havedip
# 1.0    6798
# 5.0    1946
# NaN     137
# 9.0       3
# Name: count, dtype: int64

# %% [markdown]
# I will assume 1 means high school 5 means GED, and 9 means both.
# <br>
# As for income, since she makes \\$45000, and the income level increments at \\$5000, so she's at level 9.

# %%
# Build the model
formula = ('rmarital ~ age_r + C(race) + havedip + totincr')
results = smf.mnlogit(formula, data=join).fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 1.088245
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:               rmarital   No. Observations:                 8747
# Model:                        MNLogit   Df Residuals:                     8717
# Method:                           MLE   Df Model:                           25
# Date:                Sat, 27 Jul 2024   Pseudo R-squ.:                  0.1636
# Time:                        12:25:00   Log-Likelihood:                -9518.9
# converged:                       True   LL-Null:                       -11380.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ================================================================================
#   rmarital=2       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        2.0081      0.227      8.844      0.000       1.563       2.453
# C(race)[T.2]    -0.9026      0.089    -10.181      0.000      -1.076      -0.729
# C(race)[T.3]    -0.6709      0.136     -4.925      0.000      -0.938      -0.404
# age_r           -0.0612      0.006    -10.262      0.000      -0.073      -0.050
# havedip          0.1528      0.022      7.103      0.000       0.111       0.195
# totincr         -0.1558      0.011    -13.752      0.000      -0.178      -0.134
# --------------------------------------------------------------------------------
#   rmarital=3       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -5.4312      0.782     -6.941      0.000      -6.965      -3.898
# C(race)[T.2]    -0.4743      0.238     -1.993      0.046      -0.941      -0.008
# C(race)[T.3]     0.0199      0.334      0.060      0.952      -0.635       0.675
# age_r            0.1234      0.019      6.451      0.000       0.086       0.161
# havedip          0.0248      0.056      0.442      0.659      -0.085       0.135
# totincr         -0.3388      0.031    -10.852      0.000      -0.400      -0.278
# --------------------------------------------------------------------------------
#   rmarital=4       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -1.5967      0.264     -6.050      0.000      -2.114      -1.079
# C(race)[T.2]    -0.3149      0.094     -3.342      0.001      -0.500      -0.130
# C(race)[T.3]    -0.7261      0.172     -4.230      0.000      -1.063      -0.390
# age_r            0.0678      0.007     10.213      0.000       0.055       0.081
# havedip         -0.1713      0.027     -6.245      0.000      -0.225      -0.118
# totincr         -0.2313      0.011    -20.738      0.000      -0.253      -0.209
# --------------------------------------------------------------------------------
#   rmarital=5       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.6905      0.281      2.458      0.014       0.140       1.241
# C(race)[T.2]    -1.0511      0.104    -10.105      0.000      -1.255      -0.847
# C(race)[T.3]    -0.5959      0.156     -3.816      0.000      -0.902      -0.290
# age_r            0.0053      0.007      0.720      0.471      -0.009       0.020
# havedip          0.0222      0.026      0.842      0.400      -0.029       0.074
# totincr         -0.2954      0.014    -20.772      0.000      -0.323      -0.268
# --------------------------------------------------------------------------------
#   rmarital=6       coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        5.4181      0.219     24.763      0.000       4.989       5.847
# C(race)[T.2]    -2.1494      0.081    -26.515      0.000      -2.308      -1.990
# C(race)[T.3]    -1.9422      0.138    -14.045      0.000      -2.213      -1.671
# age_r           -0.0938      0.006    -15.994      0.000      -0.105      -0.082
# havedip          0.0245      0.021      1.158      0.247      -0.017       0.066
# totincr         -0.3151      0.012    -27.167      0.000      -0.338      -0.292
# ================================================================================
# """

# %%
columns = ['age_r', 'race', 'havedip','totincr']
new = pd.DataFrame([[25,2,1,9]], columns=columns)
results.predict(new)
# Out:
#           0         1         2         3        4        5
# 0  0.674202  0.126373  0.001953  0.057003  0.03839  0.10208

# %% [markdown]
# According to our assumotion of what each unique value in the repsonse variable means, the probability of married, cohabitating, widowed, divorced, separated, or never married is shown above, respectively. Therefore she's most likely married.
